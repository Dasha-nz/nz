# %% [markdown]
# <a href="https://colab.research.google.com/github/Dasha-nz/nz/blob/main/L_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# импортирование библиотеки
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('gdrive/My Drive/L.2.csv')

# %%
# чтение файла и просмотр загруженных данных
df = pd.read_csv('gdrive/My Drive/L.2.csv')
# df = pd.read_excel('L.2.xlsx')
df.head()
# Out:
#      TY                                                 T1             AU  \
# 0  JOUR  Personalized sentiment classification of custo...     Zhang, You
# 1   NaN                                                NaN      Wang, Jin
# 2   NaN                                                NaN  Zhang, Xuejie
# 3   NaN                                                NaN            NaN
# 4  JOUR  Multi-source aggregated classification for sto...         Ma, Yu
#
#                         JO   VL      SP    PY           DA         SN  \
# 0  Knowledge-Based Systems  226  107135  2021  2021/08/17/  0950-7051
# 1                      NaN  NaN     NaN   NaN          NaN        NaN
# 2                      NaN  NaN     NaN   NaN          NaN        NaN
# 3                      NaN  NaN     NaN   NaN          NaN        NaN
# 4       Information Fusion   91     515  2023  2023/03/01/  1566-2535
#
#                                              DO  \
# 0  https://doi.org/10.1016/j.knosys.2021.107135
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4  https://doi.org/10.1016/j.inffus.2022.10.025
#
#                                                   UR                       KW  \
# 0  https://www.sciencedirect.com/science/article/...       Sentiment analysis
# 1                                                NaN      Text classification
# 2                                                NaN  Sentence representation
# 3                                                NaN       Bilinear attention
# 4  https://www.sciencedirect.com/science/article/...         Stock prediction
#
#                                                   AB   EP   IS   T2   We   In
# 0  Incorporating extra attributes of customer rev...  NaN  NaN  NaN  NaN  NaN
# 1                                                NaN  NaN  NaN  NaN  NaN  NaN
# 2                                                NaN  NaN  NaN  NaN  NaN  NaN
# 3                                                NaN  NaN  NaN  NaN  NaN  NaN
# 4  Predicting stock price movements is a challeng...  528  NaN  NaN  NaN  NaN

# %%
#удаление столбцов
df = df.drop(['TY'], axis=1)
df = df.drop(['JO'], axis=1)
df = df.drop(['VL'], axis=1)
df = df.drop(['SP'], axis=1)
df = df.drop(['DA'], axis=1)
df = df.drop(['SN'], axis=1)
df = df.drop(['UR'], axis=1)
df = df.drop(['EP'], axis=1)
df = df.drop(['IS'], axis=1)
df = df.drop(['T2'], axis=1)
df = df.drop(['We'], axis=1)
df = df.drop(['In'], axis=1)
df.head(10)
# Out:
#                                                   T1             AU    PY  \
# 0  Personalized sentiment classification of custo...     Zhang, You  2021
# 1                                                NaN      Wang, Jin   NaN
# 2                                                NaN  Zhang, Xuejie   NaN
# 3                                                NaN            NaN   NaN
# 4  Multi-source aggregated classification for sto...         Ma, Yu  2023
# 5                                                NaN       Mao, Rui   NaN
# 6                                                NaN      Lin, Qika   NaN
# 7                                                NaN       Wu, Peng   NaN
# 8                                                NaN  Cambria, Erik   NaN
# 9  TraceNet: Tracing and locating the key element...  Zhao, Qinghua  2023
#
#                                              DO                        KW  \
# 0  https://doi.org/10.1016/j.knosys.2021.107135        Sentiment analysis
# 1                                           NaN       Text classification
# 2                                           NaN   Sentence representation
# 3                                           NaN        Bilinear attention
# 4  https://doi.org/10.1016/j.inffus.2022.10.025          Stock prediction
# 5                                           NaN    Event-driven investing
# 6                                           NaN  Multi-source aggregating
# 7                                           NaN        Sentiment analysis
# 8                                           NaN                       NaN
# 9  https://doi.org/10.1016/j.knosys.2023.110792           Language models
#
#                                                   AB
# 0  Incorporating extra attributes of customer rev...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Predicting stock price movements is a challeng...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  We study sentiment analysis task where the out...

# %%
#Преобразование столбца AU в строку
df['AU'] = df['AU'].astype(str)

# %%
#Функция swap_words разбивает на слова возвращает новую строку с замененными словами.apply применяет это ко всему столбцу
def swap_words(text):
    words = text.split()
    if len(words) > 1:
        words = words[::-1]  # reverse the list of words
    return ' '.join(words)
df['AU'] = df['AU'].apply(swap_words)
df.head(10)
# Out:
#                                                   T1             AU    PY  \
# 0  Personalized sentiment classification of custo...     You Zhang,  2021
# 1                                                NaN      Jin Wang,   NaN
# 2                                                NaN  Xuejie Zhang,   NaN
# 3                                                NaN            nan   NaN
# 4  Multi-source aggregated classification for sto...         Yu Ma,  2023
# 5                                                NaN       Rui Mao,   NaN
# 6                                                NaN      Qika Lin,   NaN
# 7                                                NaN       Peng Wu,   NaN
# 8                                                NaN  Erik Cambria,   NaN
# 9  TraceNet: Tracing and locating the key element...  Qinghua Zhao,  2023
#
#                                              DO                        KW  \
# 0  https://doi.org/10.1016/j.knosys.2021.107135        Sentiment analysis
# 1                                           NaN       Text classification
# 2                                           NaN   Sentence representation
# 3                                           NaN        Bilinear attention
# 4  https://doi.org/10.1016/j.inffus.2022.10.025          Stock prediction
# 5                                           NaN    Event-driven investing
# 6                                           NaN  Multi-source aggregating
# 7                                           NaN        Sentiment analysis
# 8                                           NaN                       NaN
# 9  https://doi.org/10.1016/j.knosys.2023.110792           Language models
#
#                                                   AB
# 0  Incorporating extra attributes of customer rev...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Predicting stock price movements is a challeng...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  We study sentiment analysis task where the out...

# %%
#Переименовала столбцы
df.rename(columns = {'T1':'Title',
                     'AU':'Author',
                     'PY':'Year', 'DO':'DOI',
                     'KW':'Key Words',
                     'AB':'Abstract'},
          inplace = True)
df.head()
# Out:
#                                                Title         Author  Year  \
# 0  Personalized sentiment classification of custo...     You Zhang,  2021
# 1                                                NaN      Jin Wang,   NaN
# 2                                                NaN  Xuejie Zhang,   NaN
# 3                                                NaN            nan   NaN
# 4  Multi-source aggregated classification for sto...         Yu Ma,  2023
#
#                                             DOI                Key Words  \
# 0  https://doi.org/10.1016/j.knosys.2021.107135       Sentiment analysis
# 1                                           NaN      Text classification
# 2                                           NaN  Sentence representation
# 3                                           NaN       Bilinear attention
# 4  https://doi.org/10.1016/j.inffus.2022.10.025         Stock prediction
#
#                                             Abstract
# 0  Incorporating extra attributes of customer rev...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Predicting stock price movements is a challeng...

# %%
#Поменяла местами столбцы
df = df[['Title', 'Author', 'Year', 'Key Words', 'DOI', 'Abstract']]
df.head()
# Out:
#                                                Title         Author  Year  \
# 0  Personalized sentiment classification of custo...     You Zhang,  2021
# 1                                                NaN      Jin Wang,   NaN
# 2                                                NaN  Xuejie Zhang,   NaN
# 3                                                NaN            nan   NaN
# 4  Multi-source aggregated classification for sto...         Yu Ma,  2023
#
#                  Key Words                                           DOI  \
# 0       Sentiment analysis  https://doi.org/10.1016/j.knosys.2021.107135
# 1      Text classification                                           NaN
# 2  Sentence representation                                           NaN
# 3       Bilinear attention                                           NaN
# 4         Stock prediction  https://doi.org/10.1016/j.inffus.2022.10.025
#
#                                             Abstract
# 0  Incorporating extra attributes of customer rev...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Predicting stock price movements is a challeng...

# %%
#Удаление NAN
df.dropna()
# Out:
#                                                   Title           Author  \
# 0     Personalized sentiment classification of custo...       You Zhang,
# 4     Multi-source aggregated classification for sto...           Yu Ma,
# 9     TraceNet: Tracing and locating the key element...    Qinghua Zhao,
# 13    SKEAFN: Sentiment Knowledge Enhanced Attention...     Chuanbo Zhu,
# 20    Enhancing aspect-category sentiment analysis v...         Bin Liu,
# ...                                                 ...              ...
# 1487  DNCP: An attention-based deep learning approac...       Jie Xiong,
# 1491  Metapath and syntax-aware heterogeneous subgra...  Zhiqiang Zhang,
# 1497  Prompt learning for metonymy resolution: Enhan...       Biao Zhao,
# 1502       Pre-trained models: Past, present and future          Xu Han,
# 1526   Multi-hop question answering using sparse graphs    Nima Hemmati,
#
#       Year                           Key Words  \
# 0     2021                  Sentiment analysis
# 4     2023                    Stock prediction
# 9     2023                     Language models
# 13    2023                 Multi-view learning
# 20    2023  Aspect-category sentiment analysis
# ...    ...                                 ...
# 1487  2021               News click prediction
# 1491  2022                      Spam detection
# 1497  2023                 Metonymy resolution
# 1502  2021                  Pre-trained models
# 1526  2023         Natural language processing
#
#                                                  DOI  \
# 0       https://doi.org/10.1016/j.knosys.2021.107135
# 4       https://doi.org/10.1016/j.inffus.2022.10.025
# 9       https://doi.org/10.1016/j.knosys.2023.110792
# 13      https://doi.org/10.1016/j.inffus.2023.101958
# 20      https://doi.org/10.1016/j.knosys.2023.110339
# ...                                              ...
# 1487        https://doi.org/10.1016/j.im.2021.103428
# 1491      https://doi.org/10.1016/j.asoc.2022.109438
# 1497    https://doi.org/10.1016/j.knosys.2023.110928
# 1502    https://doi.org/10.1016/j.aiopen.2021.08.002
# 1526  https://doi.org/10.1016/j.engappai.2023.107128
#
#                                                Abstract
# 0     Incorporating extra attributes of customer rev...
# 4     Predicting stock price movements is a challeng...
# 9     We study sentiment analysis task where the out...
# 13    Multimodal sentiment analysis is an active res...
# 20    The goal of aspect-category sentiment analysis...
# ...                                                 ...
# 1487  Predicting news clicks or popularity is of gre...
# 1491  Spam Review Detection is a subclass of text cl...
# 1497  Linguistic metonymy is a common type of figura...
# 1502  Large-scale pre-trained models (PTMs) such as ...
# 1526  Multi-hop question answering (QA) across multi...
#
# [262 rows x 6 columns]
