# %% [markdown]
# <a href="https://colab.research.google.com/github/Dasha-nz/nz/blob/main/L1.1%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Имена детей в США

# %% [markdown]
# https://drive.google.com/file/d/1VRZ0ApgmM9VTCbgcFxMsEtnYsYpAotvd/view?usp=sharing
#
# #### Шаг 1. Импортируем библиотеки.

# %%
import pandas as pd

# %% [markdown]
# #### Шаг 2. Записываем данные в переменную `baby_names`

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('gdrive/My Drive/2019.csv')

# %% [markdown]
# #### Шаг 3. Смотрим первые 10 записей

# %%
df.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# #### Шаг 4. Удаляем колонки `'Unnamed: 0'` и `'Id'`

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df = df.drop(['Id'], axis=1)
df.head(5)
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %% [markdown]
# #### Шаг 5. В датасете больше мужских или женских имен?

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    558846
# M    457549
# Name: count, dtype: int64

# %% [markdown]
# #### Шаг 6. Посчитайте, сколько раз встречалось каждое имя и запишите результат в переменную `names`

# %%
df['Name'].value_counts()
df.head(5)
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %%
df.rename(columns = {'Count':'Names'}, inplace = True)
df.head(5)
# Out:
#       Name  Year Gender State  Names
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %% [markdown]
# #### Шаг 7. Сколько уникальных имен в датасете?

# %%
df['Name'].nunique()
df.nunique()
# Out:
# Name      17632
# Year         11
# Gender        2
# State        51
# Names      1949
# dtype: int64

# %% [markdown]
# #### Шаг 8. Какое самое частое имя?

# %%
df.sort_values(by='Names', ascending=False).head()
# Out:
#            Name  Year Gender State  Names
# 107416   Daniel  2004      M    CA   4167
# 110097   Daniel  2005      M    CA   3914
# 115739   Daniel  2007      M    CA   3865
# 112872   Daniel  2006      M    CA   3826
# 107417  Anthony  2004      M    CA   3805

# %% [markdown]
# #### Шаг 9. Сколько разных имен встречаются по одному разу?

# %%
df[df['Names'] == 1]
# Out:
# Empty DataFrame
# Columns: [Name, Year, Gender, State, Names]
# Index: []

# %% [markdown]
# #### Шаг 10. Какое медианное значение в `names`?

# %%
df['Names'].mean()
# Out:
# 34.85012421351935

# %% [markdown]
# #### Шаг 11. Какое среднеквадратичное отклонение значение в `names`?

# %%
df['Names'].std()
# Out:
# 97.39734648625934

# %% [markdown]
# #### Шаг 12. Сделайте саммари с `mean`, `min`, `max`, `std` и квартилями.

# %%
df.describe()
# Out:
#                Year         Names
# count  1.016395e+06  1.016395e+06
# mean   2.009053e+03  3.485012e+01
# std    3.138293e+00  9.739735e+01
# min    2.004000e+03  5.000000e+00
# 25%    2.006000e+03  7.000000e+00
# 50%    2.009000e+03  1.100000e+01
# 75%    2.012000e+03  2.600000e+01
# max    2.014000e+03  4.167000e+03
